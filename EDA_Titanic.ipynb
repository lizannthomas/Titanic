# %% [markdown]
# # EDA ( Exploratory Data Analytics)
#
# Data analysis with visual methods is called exploratory data analysis (EDA). With the use of statistical overviews and graphical representations, it is used to identify trends, patterns, or to examine assumptions.
#
# Steps in EDA are:
#
#  1. Data collection
#  2. Data Description
#  3. Data Relation
#  4. Data Preprocessing
#  5. Data Plots
#
#
# Why python?
#
#   Python is used for Machine learning,Artificial intelligence, Natural language processing etc in the data science industry beacause of its large number of libraries and due to its highly readable code it is devoloper friendly and easy to use.
#
# Libraries for EDA are:
#
#  ~Pandas
#
#  ~Numpy
#
#  ~Seaborn
#
#  ~Matplotlib
#
#  ~Autoviz
#
#  ~Sweetviz
#
#  **DATA COLLECTION**
#
#    Data collection includes the collecting, measuring and analysing of different informations.Data is gathered periodically from various audiences because it is difficult for businesses and institutes to make sensible decisions without accurate data. The legality and ethics of the data collection should be assessed as it is being conducted.
#    There are two types of data collection.They are;
#
# 1.Primary data collection
#
# 2.Secondary data collection
#
# *PRIMARY DATA COLLECTION*:  Primary data is the data collected from the main source directly. It is considered as the best type of data collection method.
# Primary data collection can further be divided into Quantitative and qualitative data collection.
#
# Some common primary data collection methods are:
#
#  ~Interviews
#
#  ~Surveys
#
#  ~Forms
#
#  ~Oral histories
#
# *SECONDARY DATA COLLECTION*:  Secondary data is an inexpensive and easier way to collect data which we refers to the already collected data ethically.
#
# Some common secondary data collection methods are:
#
# ~Internet
#
# ~Government archives
#
# ~Libraries
#
# ~Magazines
#
# ~Sales reports
#
#
# **DATA DISCRIPTION**
#
# *DISCRIPTIVE STATISTICS*:  Discriptive statistics helps us to decscribe and understands the given dataset by generating short summaries.
#
# The two main approaches are:
#
# 1. **The quantitative method** which uses mathematical operations to numerically describe and summarise data.
#
# 2. **Visualization** which illustrates data with charts, plots, histograms etc in order to get quick inferences from the data.
#
# *DATA DESCRIPTION*: We use descibe() to  get the brief description of the data set which includes mean, median, standard deviation, quartile range, minimum,maximum etc.
#
# **Understanding the dataset**:
#
#  To understand the selcted data set we use;
#
#    info(),  shape() , describe() etc.
#
# **DATA RELATION**
#
# One should have full understanding of the variable relationships of selected dataset to continue with the further analysis and to raise the quality of the findings drawn.
#  The data set variables can be categorized into two; output variable and input variable.
#
# *CORRELATION*:  The correlation determines both the direction and degree between continuos data.
#
# **Positive correlation** means that the variables are in the same direction.
#
# **Negative correlation** means that the variables are in the opposite direction.
#
# **No correlation** which means the variables are not related.
#
# **DATA PRE-PROCESSING**
#
# *Data quality* is an important factor for a data.Accuracy, completeness and consistency are the 3 elements of data quality.
#
# **Major tasks in data pre-processing**:
#
# ![data cleaning.png](data:image/png;base64,...)
#
# *Data Cleaning*:  Data cleaning includes filling of missing values, identifing and removing outliers etc.
#
# *Data Integration*:  Data integration is a process in which we combine data from different sources into a coherent data store.
#
# *Data Reduction*:  By preserving the integrity of the original data, data reduction techniques are utilised to provide a reduced version of the dataset that is substantially smaller in size.
#
#   Data reduction strategies includes;
#
#  ~ Dimensionality reduction
#
#  ~ Numerosity reduction
#
# *Data Transformation*: It transforms the data into a more easy and effective format.
#
# **DATA VISUALIZATION AND DATA PLOTS**
#
# The representation of data using charts,plots,graphics etc. are called data visualization.Since it is easy to understand pictorial representations data visualization helps in better understanding of the data.
#
# Some of the data visualization methods used in EDA are;
#
# **Heatmaps**: A 2D representation of data used to see the change in the behaviour of the data.
#
# **Countpolt**:  It is used to see the counts of observations in bins using bars.
#
# **Boxplot**:  Used to represent the summary of the dataset.
#
# **Histograms**:  Used for representing continuous data that varies over a range.
#
# **Bar graph**:  Used to represent the category of data with rectangular shaped bars.

# %%
#importing useful libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 'titanic' DATA SET
#
# The 'titanic' data set predicts the survival status of the passengers of the Titanic shipwreck.
#
# # About the 'titanic' Data set
#
# 1.   survived    : survived passengers
# 2.   pclass      : passenger class
# 3.   sex         : sex of the passenger
# 4.   age          : age of the passenger
# 5.   sibsp       : number of siblings and spouses of the passenger
# 6.   parch     : number of parents and children of the passenger
# 7.   fare          : fair paid by the passenger
# 8.   embarked       : embarkation port of the passenger
# 9.   class        : socio economic class
# 10.  who            : whether the passenger is man or woman
# 11.  adult_male       : whether the passenger is an adult male
# 12.  deck         : cabin number of the passenger
# 13.  embark_town   : embarked town of the passenger
# 14.  alive          : if the passenger is alive or not
# 15.  alone     : whether the passenger was alone or not

# %%
#loading the dataset
df=sns.load_dataset("titanic")

# %%
#printing the dataset
print(df.shape)
print(df)
# Out:
# (891, 15)
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
#checking for null values
df.isnull().values.any()
# Out:
# True

# %%
#plotting the null values
sns.heatmap(df.isnull(),yticklabels=False,cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# **UNIVARIATE AND BIVARIATE ANALYSIS**
#
# **Univariate Analysis:** Data that just contains one variable is referred to as univariate data. Since there is only one variable that varies, univariate data analysis is the most straightforward type of analysis. The analysis's primary goal is to explain the data and identify any patterns in it; it does not deal with causes or correlations. Height is an example of a univariate data.
#
# Let's say that a class of seven kids had their heights measured; the sole variable in this case was height, and it had nothing to do with causes or relationships. Drawing inferences from central tendency measures (mean, median, and mode), dispersion or spread of data (range, minimum, maximum, quartiles, variance, and standard deviation), frequency distribution tables, histograms, pie charts, frequency polygons, and bar charts can all be used to describe patterns found in this type of data.
#
# **Bivariate Analysis:** the kind of data that has two distinct variables. The analysis of this kind of data focuses on relations and causes, and it seeks to understand the logical connection between the two variables. The summertime temperature and ice cream sales are two examples of bivariate data.
#
# Assume that the two variables in a bivariate data are temperature and ice cream sales . In this case, the table makes the link between temperature and sales clear. The two variables are related because as the temperature rises, so do the sales. Accordingly, bivariate data analysis comprises contrasts, connections, causes, and explanations. To better comprehend the data, these variables are frequently shown on the graph's X and Y axes. One of these variables is independent, and the other is dependent.

# %% [markdown]
# **Countplot:**
#
# The countplot is used to represent the occurrence(counts) of the observation present in the categorical variable.
# It uses the concept of a bar chart for the visual depiction.

# %%
sns.set_style('whitegrid')
sns.countplot(x='survived',data=df)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %% [markdown]
# From this plot we can understand that about 550 people died and 350 people survived in the Titsnic incident.

# %%
sns.countplot(x='survived',hue='sex',data=df)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %% [markdown]
# From this plot among the 550 people who are dead 460 are male and 90 are female and among the survived people almost 110 are male and 240 are female. That is, more men have died and more women have survived.

# %%
sns.countplot(x='survived',hue='pclass',data=df)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %% [markdown]
# Among the people who are dead, about 80 are from class 1, 95 from class 2 and 335 are from class 3. Also among the people who survived about 140 are from class 1, 90 are from class 2 and 120 are from class 3. That is, more people from class 3 has died and more people from class 1 has survived

# %%
sns.countplot(x='survived',hue='embarked',data=df)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %% [markdown]
# More than 70% of the people boarded from Southampton, under 20% boarded from Cherbourg and the rest boarded from Queenstown. So more people who are dead and survived are from Southampton itself

# %%
sns.countplot(x='survived',hue='parch',data=df)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %% [markdown]
# Displot:
#
# We use a displot (also known as a distribution plot) to represent data in histogram form. It is a univariant set of collected data, which means the data distribution of one variable will be shown against another variable.

# %%
sns.displot(df['age'].dropna(),bins=50)

# %% [markdown]
# Among the people who were in the Titanic, most of them were of the age 20 to 40.

# %%
df['fare'].hist(bins=50)
# Out:
# <Axes: >

# %% [markdown]
# **MULTIVARIATE ANALYSIS**
#
# Multivariate data refers to data that has three or more variables. For instance, if an online marketer wanted to compare the popularity of four ads, they might analyse the click rates for men and women and then look at the correlations between the variables.
#
# It is comparable to bivariate but has more dependent variables than that. The methods used to analyse this data depend on the objectives to be met. Regression analysis, path analysis, factor analysis, and multivariate analysis of variance are a few of the methodologies.

# %%
df.corr(method='pearson')
# Out:
# <ipython-input-38-432dd9d4238b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='pearson')
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# ...

# %% [markdown]
# **Heatmap:**
#
# A depiction of rectangular data presented as a matrix with colours is called a heatmap. It accepts a 2D dataset as a parameter. It is possible to force that dataset into an ndarray. This kind of data visualisation is excellent since it can display the relationship between variables, including time.

# %%
sns.heatmap(df.corr(),annot=True,cmap='Blues_r')
# Out:
# <ipython-input-39-76a953fdf944>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap='Blues_r')
# <Axes: >

# %% [markdown]
# There are relatively strong/weak correlations between several columns.
#
# SibSp and Parch: corr(correlation coefficient) = 0.41
#
# Pclass and Fare: corr = -0.55
#
# Survived and Sex: corr = -0.54
#
# Survived and Pclass: corr = -0.34

# %% [markdown]
# **DATA CLEANING**

# %%
sns.boxplot(x='pclass',y='age',data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %% [markdown]
# From this boxplot we can find the medians of age with respect to pclass of the people in Titanic. Median of class 1 is 38, class 2 is 29 and of class 3 is 24. And there are outliers present in class 2 aand class 3.

# %%
m=df.age.isnull()
d = {1: 38, 2: 29, 3: 24}
df.loc[m, 'age'] = df.loc[m, 'pclass'].map(d)

# %%
df.drop('deck',axis=1,inplace=True)

# %%
df.dropna(inplace=True)

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# **EXPLORE CATEGORIES**

# %%
df.shape
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  889.000000  889.000000  889.000000  889.000000  889.000000  889.000000
# mean     0.382452    2.311586   29.053060    0.524184    0.382452   32.096681
# std      0.486260    0.834700   13.231443    1.103705    0.806761   49.697504
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.895800
# 50%      0.000000    3.000000   26.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   36.500000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     889 non-null    int64
#  1   pclass       889 non-null    int64
#  2   sex          889 non-null    object
#  3   age          889 non-null    float64
#  4   sibsp        889 non-null    int64
#  5   parch        889 non-null    int64
#  6   fare         889 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        889 non-null    category
#  9   who          889 non-null    object
#  10  adult_male   889 non-null    bool
#  11  embark_town  889 non-null    object
#  12  alive        889 non-null    object
#  13  alone        889 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 86.1+ KB

# %%
print(df['survived'].unique())
print(df['pclass'].unique())
print(df['sex'].unique())
# Out:
# [0 1]
# [3 1 2]
# ['male' 'female']

# %%
d1=df.select_dtypes(include=['object'])
d2=df.select_dtypes(include=['int64'])
d3=df.select_dtypes(include=['float64'])
d4=df.select_dtypes(include=['bool'])
d5=df.select_dtypes(include=['category'])
print(d1.head())
print(d2.head())
print(d3.head())
print(d4.head())
print(d5.head())
# Out:
#       sex embarked    who  embark_town alive
# 0    male        S    man  Southampton    no
# 1  female        C  woman    Cherbourg   yes
# 2  female        S  woman  Southampton   yes
# 3  female        S  woman  Southampton   yes
# 4    male        S    man  Southampton    no
#    survived  pclass  sibsp  parch
# 0         0       3      1      0
# 1         1       1      1      0
# 2         1       3      0      0
# 3         1       1      1      0
# 4         0       3      0      0
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500
#    adult_male  alone
# 0        True  False
# 1       False  False
# 2       False   True
# 3       False  False
# 4        True   True
#    class
# 0  Third
# 1  First
# 2  Third
# 3  First
# 4  Third

# %%
df.survived.value_counts()
#df.sex.value_counts()
#df.pclass.value_counts()
# Out:
# 0    549
# 1    340
# Name: survived, dtype: int64

# %% [markdown]
# **ENCODING**

# %%
enc_df=pd.get_dummies(df)
print(enc_df.shape)
print(enc_df.head())
# Out:
# (889, 24)
#    survived  pclass   age  sibsp  parch     fare  adult_male  alone  \
# 0         0       3  22.0      1      0   7.2500        True  False
# 1         1       1  38.0      1      0  71.2833       False  False
# 2         1       3  26.0      0      0   7.9250       False   True
# 3         1       1  35.0      1      0  53.1000       False  False
# 4         0       3  35.0      0      0   8.0500        True   True
#
#    sex_female  sex_male  ...  class_Second  class_Third  who_child  who_man  \
# 0           0         1  ...             0            1          0        1
# 1           1         0  ...             0            0          0        0
# 2           1         0  ...             0            1          0        0
# 3           1         0  ...             0            0          0        0
# 4           0         1  ...             0            1          0        1
#
#    who_woman  embark_town_Cherbourg  embark_town_Queenstown  \
# ...

# %% [markdown]
# **CONCLUSION**
#
# In this assignment, we selected the data set 'titanics' to perform the EDA.
# In this we have gone through the different steps of EDA like data collection, data description, data pre-processing, data visualization etc.
#
# In the dataset we had missing values and took care of it in 3 different ways.For the variable 'age', we found the mean of age with respect to pclass insert the means in the missing places.For the variable 'deck', we drop the entire column since it has more than 70 percentage of error. And for the variables like 'embarked' and 'embarked_town' we just drop the row that has missing values.
